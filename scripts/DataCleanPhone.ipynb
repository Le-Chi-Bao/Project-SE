# %%
import pandas as pd

# %%
df  = pd.read_csv('../data/reprocess/cleaned_phone_CellphoneS.csv')

# %%
df['DiscountedPrice']
# Out:
# 0         30490000
# 1         19690000
# 2         16990000
# 3         10990000
# 4         12490000
#           ...
# 464    Giá Liên Hệ
# 465    Giá Liên Hệ
# 466    Giá Liên Hệ
# 467    Giá Liên Hệ
# 468    Giá Liên Hệ
# Name: DiscountedPrice, Length: 469, dtype: object

# %%
#Discounted Price
def cleanse_price(price_str):
    if pd.isna(price_str):
        return None
    price_str = str(price_str).strip()
    if price_str == 'Giá Liên Hệ':
        return 'Giá Liên Hệ'
    try:
        return int(price_str.replace('.', '').replace('đ', '').strip())
    except ValueError:
        return None

df['DiscountedPrice'] = df['DiscountedPrice'].apply(cleanse_price)
df['DiscountedPrice']
# Out:
# 0         30490000
# 1         19690000
# 2         16990000
# 3         10990000
# 4         12490000
#           ...
# 464    Giá Liên Hệ
# 465    Giá Liên Hệ
# 466    Giá Liên Hệ
# 467    Giá Liên Hệ
# 468    Giá Liên Hệ
# Name: DiscountedPrice, Length: 469, dtype: object

# %%
df['SoldQuantity']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 464   NaN
# 465   NaN
# 466   NaN
# 467   NaN
# 468   NaN
# Name: SoldQuantity, Length: 469, dtype: float64

# %%
#SoldQuantity
import re
def convert_sold(text):
    if pd.isna(text): return None

    text = text.lower()
    text = re.sub(r'[^0-9,k,\,\.]', '', text)

    if 'k' in text:
        text = text.replace('k', '').replace(',', '.')
        return int(float(text) * 1000)
    else:
        return int(text)
df['SoldQuantity'] = df['SoldQuantity'].apply(convert_sold).astype('Int64')

print(df['SoldQuantity'])
# Out:
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
#        ...
# 464    <NA>
# 465    <NA>
# 466    <NA>
# 467    <NA>
# 468    <NA>
# Name: SoldQuantity, Length: 469, dtype: Int64

# %%
df['BatteryCapacity']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 464   NaN
# 465   NaN
# 466   NaN
# 467   NaN
# 468   NaN
# Name: BatteryCapacity, Length: 469, dtype: float64

# %%
#BatteryCapacity
import re
import pandas as pd

def cleanse_battery_capacity(capacity_str):
    if pd.isna(capacity_str):
        return None
    try:
        return int(str(capacity_str).replace(' mAh', '').replace('.', ','))
    except ValueError:
        return None


df['BatteryCapacity']  = (df["BatteryCapacity"].apply(cleanse_battery_capacity)).astype('Int64')
df['BatteryCapacity']
# Out:
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
#        ...
# 464    <NA>
# 465    <NA>
# 466    <NA>
# 467    <NA>
# 468    <NA>
# Name: BatteryCapacity, Length: 469, dtype: Int64

# %%
df['RAM']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 464   NaN
# 465   NaN
# 466   NaN
# 467   NaN
# 468   NaN
# Name: RAM, Length: 469, dtype: float64

# %%
#RAM
def cleanse_RAM(value):
    if pd.isna(value):
        return None
    ram_str = str(value).upper().replace(' ', '')

    for unit in ['GB', 'G', 'MB', 'M']:
        ram_str = ram_str.replace(unit, '')

    if ram_str.isdigit():
        return int(ram_str)
    return None

# print(df['RAM'].apply(cleanse_RAM).astype('Int64'))
df['RAM'] = df['RAM'].apply(cleanse_RAM).astype('Int64')
df['RAM']
# Out:
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
#        ...
# 464    <NA>
# 465    <NA>
# 466    <NA>
# 467    <NA>
# 468    <NA>
# Name: RAM, Length: 469, dtype: Int64

# %%
df['Resolution']
# Out:
# 0      2868x1320
# 1      2340x1080
# 2      1220x2712
# 3      1240x2772
# 4      1220x2712
#          ...
# 464     720x1280
# 465    1080x2400
# 466    3200x1440
# 467          NaN
# 468          NaN
# Name: Resolution, Length: 469, dtype: object

# %%
#Resolution
def cleanse_resolution(res_str):
    if pd.isna(res_str):
        return None
    numbers = re.findall(r'\d+', str(res_str))

    if len(numbers) >= 2:
        return f"{numbers[0]}x{numbers[1]}"
    return None

# print((df['Resolution'].apply(cleanse_resolution)).astype('string'))
df['Resolution'] = df['Resolution'].apply(cleanse_resolution)
df['Resolution'] = df['Resolution'].astype('string')
df['Resolution']
# Out:
# 0      2868x1320
# 1      2340x1080
# 2      1220x2712
# 3      1240x2772
# 4      1220x2712
#          ...
# 464     720x1280
# 465    1080x2400
# 466    3200x1440
# 467         <NA>
# 468         <NA>
# Name: Resolution, Length: 469, dtype: string

# %%
df['ROM']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 464   NaN
# 465   NaN
# 466   NaN
# 467   NaN
# 468   NaN
# Name: ROM, Length: 469, dtype: float64

# %%
#ROM
def cleanse_ROM(rom_str):
    if pd.isna(rom_str):
        return None

    rom_str = str(rom_str).upper().replace(" ", "")
    parts = rom_str.split("/")
    first_part = parts[0]

    units = {"TB": 1024, "T": 1024, "GB": 1, "G": 1}
    for unit, multiplier in units.items():
        if unit in first_part:
            num_str = first_part.replace(unit, "")
            if num_str.isdigit():
                return int(num_str) * multiplier
    if first_part.isdigit():
        return int(first_part)
    return None

# print(df['ROM'].apply(cleanse_ROM).astype('Int64'))
df['ROM'] = df['ROM'].apply(cleanse_ROM).astype('Int64')
df['ROM']
# Out:
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
#        ...
# 464    <NA>
# 465    <NA>
# 466    <NA>
# 467    <NA>
# 468    <NA>
# Name: ROM, Length: 469, dtype: Int64

# %%
df['ScreenSize']
# Out:
# 0      6.90
# 1      6.20
# 2      6.67
# 3      6.74
# 4      6.67
#        ...
# 464    4.60
# 465    6.72
# 466    6.66
# 467    6.60
# 468     NaN
# Name: ScreenSize, Length: 469, dtype: float64

# %%
#Screen Size
def cleanse_ScreenSize(value):
    if pd.isna(value):
        return None
    return float(''.join([c for c in str(value) if c.isdigit() or c == '.']))

# df['ScreenSize'].apply(cleanse_ScreenSize).astype('float64')
df['ScreenSize'] = df['ScreenSize'].apply(cleanse_ScreenSize).astype('float64')
df['ScreenSize']
# Out:
# 0      6.90
# 1      6.20
# 2      6.67
# 3      6.74
# 4      6.67
#        ...
# 464    4.60
# 465    6.72
# 466    6.66
# 467    6.60
# 468     NaN
# Name: ScreenSize, Length: 469, dtype: float64

# %%
df['NumberOfReview']
# Out:
# 0      293.0
# 1        1.0
# 2       58.0
# 3       11.0
# 4       40.0
#        ...
# 464      NaN
# 465      NaN
# 466      NaN
# 467      NaN
# 468      NaN
# Name: NumberOfReview, Length: 469, dtype: float64

# %%
#NumberOfReview
def extract_number(text):
    if pd.isna(text) or str(text).strip().lower() == 'nan' or str(text).strip() == '':
        return pd.NA
    match = re.search(r'\d+', str(text))
    return int(match.group()) if match else pd.NA

df['NumberOfReview'] = df['NumberOfReview'].apply(extract_number).astype('Int64')
df['NumberOfReview']
# Out:
# 0       293
# 1         1
# 2        58
# 3        11
# 4        40
#        ...
# 464    <NA>
# 465    <NA>
# 466    <NA>
# 467    <NA>
# 468    <NA>
# Name: NumberOfReview, Length: 469, dtype: Int64

# %%
df.to_csv('../data/reprocess/cleaned_phone_CellphoneS.csv', index=False)

# %%
df.to_json('../data/data-json/cleaned_phone_CellphoneS.json',
                    orient='records', force_ascii=False, indent=2)
